# %%
# !which conda
# Out:
# /usr/local/bin/conda

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:10
# 🔁 Restarting kernel...

# %%
import condacolab
condacolab.check()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !rm -r *
# !git clone https://github.com/nelson-lojo/in-context-learning.git
# !mv in-context-learning/* .
# !rm -r in-context-learning
# Out:
# Cloning into 'in-context-learning'...
# remote: Enumerating objects: 105, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 105 (delta 24), reused 21 (delta 16), pack-reused 61
# Receiving objects: 100% (105/105), 963.07 KiB | 16.32 MiB/s, done.
# Resolving deltas: 100% (48/48), done.
# Branch 'model-checkpointing' set up to track remote branch 'model-checkpointing' from 'origin'.
# Switched to a new branch 'model-checkpointing'

# %%
# !conda env create -f environment.yml
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | :   7% 0.0715032806610815/1 [00:04<01:41, 108.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | :  65% 0.6517280284592538/1 [00:04<00:02,  8.54s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | :  15% 0.15216044342321017/1 [00:04<00:32, 38.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | :   7% 0.073549218307399/1 [00:04<01:25, 91.77s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.3.1   | 549.3 MB  | :  16% 0.15719547772605333/1 [00:04<00:27, 32.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | :  67% 0.6702765622575767/1 [00:04<00:02,  7.85s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.11.0       | 1.02 GB   | :   8% 0.07578929602234516/1 [00:04<01:11, 77.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2022.1.0         | 129.7 MB  | :  69% 0.6909931064998595/1 [00:05<00:02,  6.96s/it]
#
#
#
#
#
#
#
#
#
#
# ...

# %%
# !conda run -n in-context-learning python src/train.py --config src/conf/toy_cloud_execution.yaml
# Out:
# Running with: Quinfig
# -------
# config: src/conf/toy_kaggle.yaml
# inherit:
# - /content/src/conf/models/standard.yaml
# - /content/src/conf/wandb.yaml
# model:
#   family: gpt2
#   n_dims: 5
#   n_embd: 256
#   n_head: 8
#   n_layer: 12
#   n_positions: 11
# out_dir: ../models/linear_regression
# test_run: false
# training:
#   batch_size: 64
#   curriculum:
#     dims:
#       end: 5
#       inc: 1
#       interval: 2000
#       start: 5
#     points:
#       end: 11
#       inc: 2
#       interval: 2000
#       start: 11
#   data: gaussian
#   keep_every_steps: 1000
#   learning_rate: 0.0001
#   num_tasks: null
#   num_training_examples: null
#   resume_id: null
#   save_every_steps: 1000
#   task: linear_regression
#   task_kwargs: {}
#   train_steps: 5001
# wandb:
#   entity: your-entity
#   log_every_steps: 100
#   name: linear_regression_toy
#   notes: ''
#   project: in-context-training
#
#
# ...
# 100%|██████████| 15/15 [00:28<00:00,  1.88s/it]

# %%
# !zip -r models.zip ../models
# Out:
#   adding: ../models/ (stored 0%)
#   adding: ../models/linear_regression/ (stored 0%)
#   adding: ../models/linear_regression/7433de35-7e5b-4300-9eec-047e2ae5f570/ (stored 0%)
#   adding: ../models/linear_regression/7433de35-7e5b-4300-9eec-047e2ae5f570/state.pt (deflated 7%)
#   adding: ../models/linear_regression/7433de35-7e5b-4300-9eec-047e2ae5f570/model_4000.pt (deflated 7%)
#   adding: ../models/linear_regression/7433de35-7e5b-4300-9eec-047e2ae5f570/model_5000.pt (deflated 7%)
#   adding: ../models/linear_regression/7433de35-7e5b-4300-9eec-047e2ae5f570/model_2000.pt (deflated 7%)
#   adding: ../models/linear_regression/7433de35-7e5b-4300-9eec-047e2ae5f570/config.yaml (deflated 50%)
#   adding: ../models/linear_regression/7433de35-7e5b-4300-9eec-047e2ae5f570/model_3000.pt (deflated 7%)
#   adding: ../models/linear_regression/7433de35-7e5b-4300-9eec-047e2ae5f570/metrics.json (deflated 68%)
# ...

# %%
from google.colab import files

# %%
print("Downloading models.zip")
files.download('models.zip')
