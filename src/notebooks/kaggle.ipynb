# %% [markdown]
# # Kaggle Running Notebook

# %% [markdown]
# ## Setup

# %% [markdown]
# #### Cloning

# %%
# !git clone https://github.com/nelson-lojo/in-context-learning.git
# !cd in-context-learning && git checkout model-checkpointing
# !cd ../
# !mv in-context-learning/* .
# !rm -r in-context-learning

# %% [markdown]
# #### Installing

# %%
# !conda env create -f environment.yml

# %%
# !conda clean -ya

# %%
import os
old_path = os.environ["PATH"]
env_name = "in-context-learning"
new_path = f"/opt/conda/envs/{env_name}/bin:{old_path}"

# %%
# %env PATH=$new_path

# %%
# %%writefile main.py

import sys

if __name__ == "__main__":
    print(sys.path)

# %%
# !/opt/conda/envs/{env_name}/bin/python ./main.py

# %% [markdown]
# ## Training

# %%
# !python src/train.py --config src/conf/toy_kaggle.yaml

# %%
# !rm -rf *

# %%
# !mv ../models ./
